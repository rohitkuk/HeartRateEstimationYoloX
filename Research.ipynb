# %%
import cv2
from PIL import Image
img =  cv2.imread('assets/me.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
c1 = (450,100)
c2 = (850,550)
img = cv2.rectangle(img, c1, c2, (255,255,255), thickness=3, lineType=cv2.LINE_AA)
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FB3A006F3D0>

# %%
import cvzone
imgover = cv2.imread('assets/happy.png', cv2.IMREAD_UNCHANGED)
imgover = cv2.cvtColor(imgover, cv2.COLOR_BGRA2RGBA)
img2 = cvzone.overlayPNG(img, imgover, [450, 100])
Image.fromarray(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FB3E1117E80>

# %%
frames = []

path = "assets/happy.png"
cap = cv2.VideoCapture(path)
ret = True
while ret:
    ret, img = cap.read() # read one frame from the 'capture' object; img is (H, W, C)
    if ret:
        frames.append(img)

# %%
len(frames)
# Out:
# 60
